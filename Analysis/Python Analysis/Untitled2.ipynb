# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Z:\\Test Data\\Raw Data\\Materials Testing\\2018-05-22\\Run 2_Imaging.csv", header = None)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-32-d66b54223798> in <module>()
# ----> 1 df = pd.read_csv("Z:\\Test Data\\Raw Data\\Materials Testing\\2018-05-22\\Run 2_Imaging.csv", header = None)
#
# ...

# %%
len(df.values[1])
pics = df.values.reshape((33,480,640))

# %%
levels = np.unique(pics[0])

# %%
plt.contourf(pics[22][::-1], levels = levels)
