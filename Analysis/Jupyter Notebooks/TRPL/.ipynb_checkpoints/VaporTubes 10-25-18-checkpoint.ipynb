# %%
import os
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import datetime
from datetime import timedelta as td
import pandas as pd
# %matplotlib inline
import sys
import easygui

import json


from nptdms import TdmsFile as TF

import importlib

import mhdpy.load as load
import mhdpy.analysis as analysis

mpl.rcParams.update({'font.size': 14})

datafolder = "C:\\Users\\aspit\\OneDrive\\Data\\"

# %%
folders = [datafolder + "\\2018-10-25\\Proj_VaporTubes\\Reprate_Pow\\",datafolder + "\\2018-10-26\\Proj_VaporTubes\\Reprate_40C\\",datafolder + "\\2018-10-26\\Proj_VaporTubes\\Reprate\\" ]

fps_PL = []
fps_pow = []
fps_T = []

for folder in folders:
    contents = os.listdir(folder)
    for content in contents:
        fname = os.path.splitext(content)[0]
        if 'PIMAX' in fname:
            fps_PL.append(os.path.join(folder,content))
        elif 'Powermeter' in fname:
            fps_pow.append(os.path.join(folder,content))
        elif 'TC1' in fname:
            fps_T.append(os.path.join(folder,content)) 

dfs_PL = load.common.create_tcdict(fps_PL,load.spe.spe2df_spect,prefixes = ['PIMAX_1_'])
dfs_pow = load.common.create_tcdict(fps_pow,load.common.tdms2df,prefixes = ['Log_Powermeter_0_','Log_Powermeter_1_'])
dfs_T = load.common.create_tcdict(fps_T,load.common.tdms2df,prefixes = ['Log_TC1_'])

regexs = {'Temperature' : '(\d+)C_', 'Power': '_(\d+)kV', 'Reprate': '_(\d+)Hz' }

dfs_PL = load.common.tcdict2mi(dfs_PL, regexs)
dfs_pow = load.common.tcdict2mi(dfs_pow, regexs)
dfs_T = load.common.tcdict2mi(dfs_T, regexs)

dfs_PL.sort_index(level = 'Temperature', inplace = True)
dfs_pow.sort_index(level = 'Temperature', inplace = True)
dfs_T.sort_index(level = 'Temperature', inplace = True)

filepath_EL = ['C:\\Users\\aspit\\OneDrive\\Data\\2018-10-25\\Eventlog.json']
with open(filepath_EL[0]) as read_file:
    eventlog = json.load(read_file)
# Out:
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# ...

# %%
# levels = dfs.index.remove_unused_levels().levels
def plotgrid(dfs, colsel = None):
    #use colsel to select the column in the final dataframe to be plotted, if blank then plot all or series
    dfs = dfs.swaplevel(0,1).sort_index()

    levels = dfs.index.levels

    ncol = len(levels[0])
    nrow = len(levels[1])

    colname = levels[0].name
    rowname = levels[1].name

    fig, axes = plt.subplots(nrow,ncol,sharey = True, sharex=True, figsize = (3*ncol,3*nrow))

    for i, col in enumerate(levels[0]):
        for j, row in enumerate(levels[1]):
            if len(axes.shape) == 1:
                ax = axes[i]
            else:
                ax = axes[j][i]
            if(i==0):
                ax.set_ylabel(rowname +": " +str(row)+ '\n'+ 'Counts (a.u.)')
        #     print(col,dfs.index.levels[])
        #     if(col in dfs.columns):
            if col in dfs.index:
                dfs_i = dfs.loc[col]

                if row in dfs_i.index:
                    trace = dfs_i.loc[row][0]
                    if(colsel != None):
                        trace = trace[trace.columns[colsel]]
                    ax.plot(trace)

                if(j==0):
                    ax.set_title(colname + ": " + str(col))
                if(j==nrow-1):
                    ax.set_xlabel('Wavelength (nm)')
    return fig, axes

# %%
dfs_PL_cut = dfs_PL.copy()
for testcase in dfs_PL.index:
    dfin = dfs_PL.loc[testcase][0] #These zeros are because 
    dfout = analysis.trpl.cutspectraldf(dfin, 778,782)
    dfs_PL_cut.loc[testcase][0] = dfout
    
levelnum = 1
value = 14.0

print('Cross section of ' + dfs_PL_cut.index.names[levelnum] +" = " + str(value))
dfs = dfs_PL_cut.xs(value, level = levelnum)
 
plotgrid(dfs)
# Out:
# Cross section of Power = 14.0

# %%
dfs_pow_m1 = dfs_pow.copy()
for testcase in dfs_pow_m1.index:
    dfin = dfs_pow.loc[testcase][0] #These zeros dependon the dimension of the multi index... need to just get one dataframe
    #dfout = analysis.trpl.cutspectraldf(dfin, 778,782)
    dfout = pd.DataFrame(dfin['/\'Meter 1\'/\'Power\''])
    dfs_pow_m1.loc[testcase][0] = dfout
    testcase=testcase
    
# dfs_pow_m1
levelnum = 1
value = 15.0

print('Cross section of ' + dfs_pow_m1.index.names[levelnum] +" = " + str(value))
dfs = dfs_pow_m1.xs(value, level = levelnum)

plotgrid(dfs)
# Out:
# Cross section of Power = 15.0

# %%
dfs_T.iloc[0][0]
# Out:
#                             /'TC1'/'Temperature_0'  /'TC1'/'Temperature_1'  \
# 2018-10-26 17:13:26.913941               21.186310               21.152106
# 2018-10-26 17:13:27.013941               21.175733               21.142823
# 2018-10-26 17:13:27.113941               21.179985               21.157799
# 2018-10-26 17:13:27.213941               21.182234               21.153947
# 2018-10-26 17:13:27.313941               21.172028               21.158346
# 2018-10-26 17:13:27.413941               21.187104               21.148093
# 2018-10-26 17:13:27.513941               21.183744               21.150650
# 2018-10-26 17:13:27.613941               21.175678               21.159778
# 2018-10-26 17:13:27.713941               21.178413               21.146243
# 2018-10-26 17:13:27.813941               21.177721               21.148139
# 2018-10-26 17:13:27.913941               21.170387               21.136182
# ...

# %%
dfs_T_cut = dfs_T.copy()
for testcase in dfs_T_cut.index:
    dfin = dfs_T_cut.loc[testcase][0] #These zeros dependon the dimension of the multi index... need to just get one dataframe
    dfout = pd.DataFrame(dfin['/\'TC1\'/\'Temperature_0\''])
    dfs_T_cut.loc[testcase][0] = dfout
#     testcase=testcase


# # dfs_pow_m1
levelnum = 0
value = 60.0

print('Cross section of ' + dfs_T_cut.index.names[levelnum] +" = " + str(value))
dfs = dfs_T_cut.xs(value, level = levelnum)


plotgrid(dfs)
# Out:
# Cross section of Temperature = 60.0

# %%
maximums = dfs_PL_cut.copy()
for filename in dfs_PL_cut.index:
    maximums.loc[filename][0] = dfs_PL_cut.loc[filename][0].max()[0]
    
# maximums = maximums.swaplevel(0,1).sort_index()

lns = []
for temp in maximums.index.levels[0]:
    plt.plot(maximums.loc[temp],marker = 'o', label = str(temp) + "C")
    plt.title('Rep Rate Dependence')
    plt.xlabel('Rep Rate (Hz)')
    plt.ylabel('Maximum (counts)')
plt.legend()

# %%
# import plotly

df = maximums.unstack()[0]

x = df.columns.values
y = df.index.values

x = np.append(x,70)
y = np.append(y,120)
print(x)

X,Y = np.meshgrid(x,y)

data = df.values.tolist()

data[0][0] = 10000


fig, ax = plt.subplots(1)

plot = ax.pcolormesh(x,y,data)
ax.set_xlabel('Temp (C)')
ax.set_ylabel('Rep Rate (Hz)')
plt.colorbar(plot)
# ax.set_xlim([30,70])
# img = plt.pcolormesh(data)
#plt.axis([0,120,0,100])


data[0][0]
# data = [plotly.graph_objs.Heatmap( z=df.values.tolist(), colorscale='Viridis')]

# plotly.plotly.iplot(data, filename = 'pandas_heatmap')
# Out:
# [30. 50. 60. 70.]
# 10000

# %%
# fig, ax = plt.subplots(1,5,sharey = True, figsize = (20,4))

# i=0
# for filename in dfs_pow:
#     meter1 = dfs_pow[filename]['/\'Meter 1\'/\'Power\'']
#     meter2 = dfs_pow[filename]['/\'Meter 2\'/\'Power\'']
#     ratio = meter1/meter2
#     ax[i].plot(dfs_pow[filename]['/\'Meter 1\'/\'Time_LV\''],meter1)
#     ax[i].plot(dfs_pow[filename]['/\'Meter 2\'/\'Time_LV\''],meter2)
#     ax[i].set_title(filename)
#     ax[i].legend(dfs_pow[filename].columns)
#     ax[i].plot(meter1)
#     i=i+1
    
# fig.autofmt_xdate()
