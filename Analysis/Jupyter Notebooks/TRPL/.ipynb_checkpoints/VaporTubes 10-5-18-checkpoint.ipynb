# %%
import os
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import datetime
from datetime import timedelta as td
import pandas as pd
# %matplotlib inline
import sys

#Make sure Python Analysis folder in in PYTHONPATH and import the mhdpy module
#PythonAnalysisPath = 'C:\\Users\\aspit\\Git\\MHDLab\\Analysis\\Python Analysis'
#if not PythonAnalysisPath in sys.path:
#    sys.path.append(PythonAnalysisPath)
#print(sys.path)

import easygui

from nptdms import TdmsFile as TF

import importlib

import mhdpy.load as load
import mhdpy.analysis as analysis

mpl.rcParams.update({'font.size': 18})

# %%
folder = "C:\\Users\\aspit\\OneDrive\\Data\\2018-10-05\\Proj_VaporTubes\\Rep Rate 500Aq"

#filepaths = easygui.fileopenbox(multiple=True,default = folder)
filepaths = ['C:\\Users\\aspit\\OneDrive\\Data\\2018-10-05\\Proj_VaporTubes\\Rep Rate 500Aq\\PI_Cam1_10Hz.spe', 'C:\\Users\\aspit\\OneDrive\\Data\\2018-10-05\\Proj_VaporTubes\\Rep Rate 500Aq\\PI_Cam1_20Hz.spe', 'C:\\Users\\aspit\\OneDrive\\Data\\2018-10-05\\Proj_VaporTubes\\Rep Rate 500Aq\\PI_Cam1_50Hz.spe', 'C:\\Users\\aspit\\OneDrive\\Data\\2018-10-05\\Proj_VaporTubes\\Rep Rate 500Aq\\PI_Cam1_100Hz.spe', 'C:\\Users\\aspit\\OneDrive\\Data\\2018-10-05\\Proj_VaporTubes\\Rep Rate 500Aq\\PI_Cam1_200Hz.spe']

dfs = load.common.create_tcdict(filepaths,load.spe.spe2df_spect,prefix = 'PI_Cam1_')

dfs_cut = {}
for testcase in dfs:
    dfs_cut[testcase] = analysis.trpl.cutspectraldf(dfs[testcase], 778,781)

reprates = [10,20,50,100,200]

maximums = []
for filename in dfs_cut:
    maximums.append(dfs_cut[filename].max()[0])
# Out:
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object

# %%
fig, ax = plt.subplots(1,5,sharey = True, figsize = (20,4))

i=0
for filename in dfs_cut:
    ax[i].plot(dfs_cut[filename].index,dfs_cut[filename])
    ax[i].set_title(filename)
    ax[i].legend(dfs_cut[filename].columns)
    i=i+1

    #Fullrangeplot = SPEparse.SpectraPlot(PI_Cam1_60C_10Hz_cut, PI_Cam1_60C_10Hz_cut.index)

# %%
plt.plot(reprates,maximums)

# %%
folder = "C:\\Users\\aspit\\OneDrive\\Data\\2018-10-05\\Proj_VaporTubes\\TempandReprate 2"

#filepaths = easygui.fileopenbox(multiple=True,default = folder)
filepaths = ['C:\\Users\\aspit\\OneDrive\\Data\\2018-10-05\\Proj_VaporTubes\\TempandReprate 2\\PI_Cam1_60C_10Hz.spe', 'C:\\Users\\aspit\\OneDrive\\Data\\2018-10-05\\Proj_VaporTubes\\TempandReprate 2\\PI_Cam1_60C_20Hz_3.spe', 'C:\\Users\\aspit\\OneDrive\\Data\\2018-10-05\\Proj_VaporTubes\\TempandReprate 2\\PI_Cam1_60C_50Hz.spe', 'C:\\Users\\aspit\\OneDrive\\Data\\2018-10-05\\Proj_VaporTubes\\TempandReprate 2\\PI_Cam1_60C_100Hz.spe', 'C:\\Users\\aspit\\OneDrive\\Data\\2018-10-05\\Proj_VaporTubes\\TempandReprate 2\\PI_Cam1_60C_200Hz_3.spe']

dfs = load.common.create_tcdict(filepaths,load.spe.spe2df_spect,prefix = 'PI_Cam1_')

dfs_cut = {}
for testcase in dfs:
    dfs_cut[testcase] = analysis.trpl.cutspectraldf(dfs[testcase], 778,781)

reprates = [10,20,50,100,200]

# maximums = []
# for filename in dfs_cut:
#     maximums.append(dfs[filename].max()[0])
    
maximums = []

for testcase in dfs_cut:
    maxtemp = []
    for idx in dfs_cut[testcase].columns:
        maxtemp.append(dfs_cut[testcase][idx].max())

    maximums.append(maxtemp)

maximums
# Out:
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# Successfully loaded 1 file(s) in a SpeFile object
# [[12733.0, 18583.0, 15785.0, 13714.0, 16035.0],
#  [10623.0, 18954.0, 13862.0, 14533.0, 8732.0],
#  [15361.0, 14976.0, 15080.0, 10875.0, 11729.0],
#  [12885.0, 11459.0, 12324.0, 13261.0, 9490.0],
#  [17532.0, 10837.0, 14880.0, 10880.0, 8270.0]]

# %%
fig, ax = plt.subplots(1,5,sharey = True, figsize = (20,4))

i=0
for filename in dfs_cut:   
    ax[i].plot(dfs_cut[filename].index,dfs_cut[filename])
    ax[i].set_title(filename)
    ax[i].legend(dfs_cut[filename].columns)
    i=i+1

# %%
for maxarray in maximums:
    plt.plot([1,2,3,4,5],maxarray)
plt.legend(reprates)
plt.xlabel('frame #')
# Out:
# Text(0.5,0,'frame #')
